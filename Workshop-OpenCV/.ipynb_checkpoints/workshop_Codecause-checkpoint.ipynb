# %%
from PIL import Image

# %%
img = Image.open("panda.jpg")

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
arr = np.array(img)
arr.shape # 3 represents rgb layer
# Out:
# (225, 225, 3)

# %%
plt.imshow(arr)

# %%
face = arr[15:110,60:160] #row then column

# %%
plt.imshow(face)
