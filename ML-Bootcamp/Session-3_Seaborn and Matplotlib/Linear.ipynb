# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
x = np.linspace(2, 20, 10)
m, c = 3, 10

# %%
y = m * x + c

# %%
plt.plot(x,y)

# %%
plt.scatter(x, y)

# %%
x = np.linspace(2, 20, 1000)
m, c = 3, 10
y = m * x + c

# %%
noise = np.random.randn(1000) * 5 # to create some separation

# %%
y_mod = y + noise

# %%
plt.scatter(x, y_mod)

# %%
x = np.random.randn(1000) #rand

# %%
out = plt.hist(x, bins=100) #bins == towers
plt.show(out)

# %%
x = np.random.randint(-4, 4, 1000) #rand int

# %%
plt.show(plt.hist(x, bins=100))

# %%
out = plt.pie([10, 20, 30], explode=[0, .1, 0], shadow=True, radius=2) # 1/6, 1/3, 1/2

# %%
import seaborn as sns

# %%
x = np.random.randn(1000)

# %%
sns.distplot(x,bins = 30) #histogram distributuon, curve is KDE

# %%
plt.figure(figsize=(4, 4))
sns.distplot(x, bins=30, kde=False, rug=True)# rug = density

# %%
data = sns.load_dataset("tips") # tips is already included in seaborn

# %%
data.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
sns.scatterplot(data["total_bill"], data["tip"], hue=data["smoker"]) # x , y, 3rd variable smoker

# %%
sns.violinplot(y=data.total_bill)

# %%
X, y= load_boston(return_X_y=True) #give both obejcts x n y separately

# %%
sns.violinplot(y=y)

# %%
sns.boxplot(y=y)
